# %%
<html>
   <head>
      <meta charset="UTF-8" />
      <link rel="stylesheet" type="text/css" href="css/style.css">
      <style>
        body {
            text-align: center;
        }
        .btn {
            background-color:#f44336; /* Green */
            border: none;
            color: white;
            padding: 100px 32px;
            width: 50%;
            height: 30%;
            text-align: center;
            text-decoration: none;
            display: inline-block;
            font-size: 100px;
}
    </style>
   </head>
   <?php
      if (isset($_POST['LightON'])) {
          exec("sudo python /home/pi/codes/servotestapache.py");
      }
   ?>
   <form method="post">
      <button class="btn" name="LightON">ENgage SERVO</button>&nbsp;
   </form>
</html>

# %%
<?php 
ip/index.php?leds1=1&leds2=0&co=1x
if (isset($_GET['leds1'])) {	
	if($_GET['leds1'] == 1) {
		exec("sudo python /home/pi/codes/apachetest/servotest1.py");
	} else {
	}
}
if(isset($_GET['leds2'])) {
	if($_GET['leds2'] == 1) {
		exec("sudo python /home/pi/codes/apachetest/servotest2.py");
	} else {
	}
}
if(isset($_GET['leds3'])) {
	if($_GET['leds3'] == 1) {
		exec("sudo python /home/pi/codes/apachetest/servotest3.py");
	} else {
	}
}
if(isset($_GET['led3'])) {
	if($_GET['led3'] == 1) {
		exec("sudo python /home/pi/codes/servotestapache.py");
	} else {
		exec("sudo python /home/pi/codes/servotestapache.py");
	}
}
?>

# %%
<?php 

if (isset($_GET['led1'])) {	
	if($_GET['led1'] == 1) {
		exec("sudo python /home/pi/codes/servotestapache.py");// pin 0 in wiring pi is gpio 17
	} else {
		exec("sudo python /home/pi/codes/servotestapache.py");
	}
}
if(isset($_GET['led2'])) {
	if($_GET['led2'] == 1) {
		exec("sudo python /home/pi/codes/servotestapache.py");
	} else {
		exec("sudo python /home/pi/codes/servotestapache.py");
	}
}
if(isset($_GET['led3'])) {
	if($_GET['led3'] == 1) {
		exec("sudo python /home/pi/codes/servotestapache.py");
	} else {
		exec("sudo python /home/pi/codes/servotestapache.py");
	}
}
?>
